# %%
 # %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
 # Tell matplotlib to create a scatter plot based upon the above data

plt.scatter(temp, sales, facecolors="yellow", edgecolors="black")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
 # Set the upper and lower limits of our y axis
plt.ylim(0, max(sales)+50)
# Out:
# (0.0, 664.0)

# %%
 # Set the upper and lower limits of our x axis

plt.xlim(10, len(temp)+10)
# Out:
# (10.0, 22.0)

# %%
 # Create a title, x label, and y label for our chart
plt.title("Ice Cream Sales by Temperature")
plt.xlabel("Ice Cream Sales")
plt.ylabel("Temperature")
# Out:
# Text(76.56944444444443, 0.5, 'Temperature')

# %%
plt.savefig("ICSalesbytemp.png")
