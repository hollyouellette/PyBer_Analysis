# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(cities, bars_in_cities, color='b', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
# Action for Variable in Container
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"] )
# Out:
# ([<matplotlib.axis.XTick at 0x7ffe428d3400>,
#   <matplotlib.axis.XTick at 0x7ffe428d33d0>,
#   <matplotlib.axis.XTick at 0x7ffe428eb940>,
#   <matplotlib.axis.XTick at 0x7ffe428f4d60>,
#   <matplotlib.axis.XTick at 0x7ffe41eae580>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities)+1)
# Out:
# (0.0, 9.6)

# %%
# Give the chart a title, x label, and y label

plt.title("Bars in US Cities")
plt.xlabel("Cities")
plt.ylabel("Number of Bars")
# Out:
# Text(111.81944444444443, 0.5, 'Number of Bars')

# %%
# Save an image of the chart and print it to the screen
